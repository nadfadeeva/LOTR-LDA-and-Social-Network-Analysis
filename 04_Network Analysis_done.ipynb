# %% [markdown]
# **Делаем сетевой анализ персонажей, где метриками выступают:**
#
# * Популярность - как часто персонаж упоминается рядом с другими
#
# * Связующая роль - кто соединяет разные группы героев
#
# * Близость к центру - кто быстрее всех "дотянется" до любого другого героя

# %%
import pandas as pd
import networkx as nx
from itertools import combinations
import re
import pickle

from natasha import (
    Segmenter,
    MorphVocab,
    NewsEmbedding,
    NewsMorphTagger,
    NewsSyntaxParser,
    Doc
)

segmenter = Segmenter()
morph_vocab = MorphVocab()
emb = NewsEmbedding()
morph_tagger = NewsMorphTagger(emb)
syntax_parser = NewsSyntaxParser(emb)
emb = NewsEmbedding()
syntax_parser = NewsSyntaxParser(emb)
# Out:
# C:\Users\Huawei\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.13_qbz5n2kfra8p0\LocalCache\local-packages\Python313\site-packages\pymorphy2\analyzer.py:114: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
with open('processed_data.pkl', 'rb') as f:
    base_data = pickle.load(f)

segments = base_data['segments']
my_mapping = base_data['my_mapping']
book1_end = base_data['book1_end']
book2_end = base_data['book2_end']

# %%
def get_network_metrics(segments, entity_mapping, window_size=50):
    G = nx.Graph()
    target_entities = set(entity_mapping.values())
    
    # Сбор связей
    for text in segments:
        words = re.sub(r'[^а-яё\_\s]', ' ', text.lower()).split()
        for i in range(len(words) - window_size + 1):
            window = words[i : i + window_size]
            found = list(set([word for word in window if word in target_entities]))
            if len(found) > 1:
                for char_a, char_b in combinations(sorted(found), 2):
                    if G.has_edge(char_a, char_b):
                        G[char_a][char_b]['weight'] += 1
                    else:
                        G.add_edge(char_a, char_b, weight=1)

    # Степень центральности
    degree = nx.degree_centrality(G)
    # Посредничество
    betweenness = nx.betweenness_centrality(G, weight='weight')
    # Близость
    closeness = nx.closeness_centrality(G)

    # Собираем в таблицу
    metrics_df = pd.DataFrame({
        'Персонаж': list(degree.keys()),
        'Популярность': list(degree.values()),
        'Связующая роль': list(betweenness.values()),
        'Близость к центру': list(closeness.values())
    })
    
    return metrics_df.sort_values(by='Связующая роль', ascending=False), G

df_network, G = get_network_metrics(segments, my_mapping)

# %%
# Создаем черный список для локаций и нарицательных имен
blacklist = [
    'средиземье', 'хоббитания', 'лихолесье', 'осгилиат', 'пригорье',
    'мордор', 'ривенделл', 'шир', 'рохан', 'гондор', 'арнор', 'раздол',
    'минас_тирит', 'изенгард', 'лориэн', 'мория', 'хоббит', 'ристания', 'том'
]

df_final = df_network[~df_network['Персонаж'].isin(blacklist)].copy()
df_final = df_final.sort_values(by='Связующая роль', ascending=False).head(20)

styled_table = df_final.style \
    .background_gradient(cmap='Blues', subset=['Популярность']) \
    .background_gradient(cmap='Oranges', subset=['Связующая роль']) \
    .format({
        'Популярность': '{:.3f}',
        'Связующая роль': '{:.3f}',
        'Близость к центру': '{:.3f}'
    }) \
    .set_caption("Сетевые метрики персонажей: Популярность vs Влияние")

styled_table
# Out:
# <style type="text/css">
# #T_b1c21_row0_col1 {
#   background-color: #9cc9e1;
#   color: #000000;
# }
# #T_b1c21_row0_col2 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_b1c21_row1_col1 {
#   background-color: #2b7bba;
#   color: #f1f1f1;
# }
# #T_b1c21_row1_col2 {
#   background-color: #cd4401;
#   color: #f1f1f1;
# }
# #T_b1c21_row2_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_b1c21_row2_col2 {
#   background-color: #f36e19;
#   color: #f1f1f1;
# }
# #T_b1c21_row3_col1, #T_b1c21_row17_col1 {
#   background-color: #2070b4;
#   color: #f1f1f1;
# }
# #T_b1c21_row3_col2 {
#   background-color: #fdae6a;
#   color: #000000;
# }
# #T_b1c21_row4_col1 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_b1c21_row4_col2 {
#   background-color: #fdaf6c;
#   color: #000000;
# }
# #T_b1c21_row5_col1 {
#   background-color: #87bddc;
#   color: #000000;
# }
# #T_b1c21_row5_col2 {
#   background-color: #fdb06e;
#   color: #000000;
# }
# #T_b1c21_row6_col1 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_b1c21_row6_col2 {
#   background-color: #fdd1a3;
#   color: #000000;
# }
# #T_b1c21_row7_col1 {
#   background-color: #e9f2fa;
#   color: #000000;
# }
# #T_b1c21_row7_col2 {
#   background-color: #fdd5ab;
#   color: #000000;
# }
# #T_b1c21_row8_col1 {
#   background-color: #4493c7;
#   color: #f1f1f1;
# }
# #T_b1c21_row8_col2 {
#   background-color: #fedcb9;
#   color: #000000;
# }
# #T_b1c21_row9_col1 {
#   background-color: #8fc2de;
#   color: #000000;
# }
# #T_b1c21_row9_col2 {
#   background-color: #fee4ca;
#   color: #000000;
# }
# #T_b1c21_row10_col1, #T_b1c21_row18_col1 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_b1c21_row10_col2 {
#   background-color: #fee6ce;
#   color: #000000;
# }
# #T_b1c21_row11_col1 {
#   background-color: #edf4fc;
#   color: #000000;
# }
# #T_b1c21_row11_col2 {
#   background-color: #fee8d2;
#   color: #000000;
# }
# #T_b1c21_row12_col1 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_b1c21_row12_col2 {
#   background-color: #feeddb;
#   color: #000000;
# }
# #T_b1c21_row13_col1 {
#   background-color: #529dcc;
#   color: #f1f1f1;
# }
# #T_b1c21_row13_col2 {
#   background-color: #feeddc;
#   color: #000000;
# }
# #T_b1c21_row14_col1 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_b1c21_row14_col2 {
#   background-color: #ffeede;
#   color: #000000;
# }
# #T_b1c21_row15_col1 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_b1c21_row15_col2 {
#   background-color: #fff1e3;
#   color: #000000;
# }
# #T_b1c21_row16_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_b1c21_row16_col2 {
#   background-color: #fff4e9;
#   color: #000000;
# }
# #T_b1c21_row17_col2 {
#   background-color: #fff5ea;
#   color: #000000;
# }
# #T_b1c21_row18_col2, #T_b1c21_row19_col2 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_b1c21_row19_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b1c21">
#   <caption>Сетевые метрики персонажей: Популярность vs Влияние</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1c21_level0_col0" class="col_heading level0 col0" >Персонаж</th>
#       <th id="T_b1c21_level0_col1" class="col_heading level0 col1" >Популярность</th>
#       <th id="T_b1c21_level0_col2" class="col_heading level0 col2" >Связующая роль</th>
#       <th id="T_b1c21_level0_col3" class="col_heading level0 col3" >Близость к центру</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1c21_level0_row0" class="row_heading level0 row0" >26</th>
#       <td id="T_b1c21_row0_col0" class="data row0 col0" >саурон</td>
#       <td id="T_b1c21_row0_col1" class="data row0 col1" >0.275</td>
#       <td id="T_b1c21_row0_col2" class="data row0 col2" >0.229</td>
#       <td id="T_b1c21_row0_col3" class="data row0 col3" >0.576</td>
#     </tr>
#     <tr>
#       <th id="T_b1c21_level0_row1" class="row_heading level0 row1" >19</th>
#       <td id="T_b1c21_row1_col0" class="data row1 col0" >пин</td>
#       <td id="T_b1c21_row1_col1" class="data row1 col1" >0.475</td>
#       <td id="T_b1c21_row1_col2" class="data row1 col2" >0.187</td>
#       <td id="T_b1c21_row1_col3" class="data row1 col3" >0.650</td>
#     </tr>
#     <tr>
#       <th id="T_b1c21_level0_row2" class="row_heading level0 row2" >52</th>
#       <td id="T_b1c21_row2_col0" class="data row2 col0" >лучиэнь</td>
#       <td id="T_b1c21_row2_col1" class="data row2 col1" >0.044</td>
#       <td id="T_b1c21_row2_col2" class="data row2 col2" >0.155</td>
#       <td id="T_b1c21_row2_col3" class="data row2 col3" >0.424</td>
#     </tr>
#     <tr>
#       <th id="T_b1c21_level0_row3" class="row_heading level0 row3" >9</th>
#       <td id="T_b1c21_row3_col0" class="data row3 col0" >сэм</td>
#       <td id="T_b1c21_row3_col1" class="data row3 col1" >0.500</td>
#       <td id="T_b1c21_row3_col2" class="data row3 col2" >0.111</td>
#       <td id="T_b1c21_row3_col3" class="data row3 col3" >0.664</td>
#     </tr>
#     <tr>
#       <th id="T_b1c21_level0_row4" class="row_heading level0 row4" >16</th>
#       <td id="T_b1c21_row4_col0" class="data row4 col0" >горлум</td>
#       <td id="T_b1c21_row4_col1" class="data row4 col1" >0.194</td>
#       <td id="T_b1c21_row4_col2" class="data row4 col2" >0.110</td>
#       <td id="T_b1c21_row4_col3" class="data row4 col3" >0.544</td>
#     </tr>
#     <tr>
#       <th id="T_b1c21_level0_row5" class="row_heading level0 row5" >49</th>
#       <td id="T_b1c21_row5_col0" class="data row5 col0" >элронд</td>
#       <td id="T_b1c21_row5_col1" class="data row5 col1" >0.306</td>
#       <td id="T_b1c21_row5_col2" class="data row5 col2" >0.109</td>
#       <td id="T_b1c21_row5_col3" class="data row5 col3" >0.586</td>
#     </tr>
#     <tr>
#       <th id="T_b1c21_level0_row6" class="row_heading level0 row6" >0</th>
#       <td id="T_b1c21_row6_col0" class="data row6 col0" >бильбо</td>
#       <td id="T_b1c21_row6_col1" class="data row6 col1" >0.356</td>
#       <td id="T_b1c21_row6_col2" class="data row6 col2" >0.086</td>
#       <td id="T_b1c21_row6_col3" class="data row6 col3" >0.597</td>
#     </tr>
#     <tr>
#       <th id="T_b1c21_level0_row7" class="row_heading level0 row7" >61</th>
#       <td id="T_b1c21_row7_col0" class="data row7 col0" >балин</td>
#       <td id="T_b1c21_row7_col1" class="data row7 col1" >0.088</td>
#       <td id="T_b1c21_row7_col2" class="data row7 col2" >0.082</td>
#       <td id="T_b1c21_row7_col3" class="data row7 col3" >0.495</td>
#     </tr>
#     <tr>
#       <th id="T_b1c21_level0_row8" class="row_heading level0 row8" >62</th>
#       <td id="T_b1c21_row8_col0" class="data row8 col0" >гимли</td>
#       <td id="T_b1c21_row8_col1" class="data row8 col1" >0.419</td>
#       <td id="T_b1c21_row8_col2" class="data row8 col2" >0.075</td>
#       <td id="T_b1c21_row8_col3" class="data row8 col3" >0.632</td>
#     </tr>
#     <tr>
#       <th id="T_b1c21_level0_row9" class="row_heading level0 row9" >99</th>
#       <td id="T_b1c21_row9_col0" class="data row9 col0" >эомер</td>
#       <td id="T_b1c21_row9_col1" class="data row9 col1" >0.294</td>
#       <td id="T_b1c21_row9_col2" class="data row9 col2" >0.066</td>
#       <td id="T_b1c21_row9_col3" class="data row9 col3" >0.578</td>
#     </tr>
#     <tr>
#       <th id="T_b1c21_level0_row10" class="row_heading level0 row10" >152</th>
#       <td id="T_b1c21_row10_col0" class="data row10 col0" >шаркич</td>
#       <td id="T_b1c21_row10_col1" class="data row10 col1" >0.056</td>
#       <td id="T_b1c21_row10_col2" class="data row10 col2" >0.064</td>
#       <td id="T_b1c21_row10_col3" class="data row10 col3" >0.473</td>
#     </tr>
#     <tr>
#       <th id="T_b1c21_level0_row11" class="row_heading level0 row11" >34</th>
#       <td id="T_b1c21_row11_col0" class="data row11 col0" >брендидуим</td>
#       <td id="T_b1c21_row11_col1" class="data row11 col1" >0.075</td>
#       <td id="T_b1c21_row11_col2" class="data row11 col2" >0.061</td>
#       <td id="T_b1c21_row11_col3" class="data row11 col3" >0.498</td>
#     </tr>
#     <tr>
#       <th id="T_b1c21_level0_row12" class="row_heading level0 row12" >28</th>
#       <td id="T_b1c21_row12_col0" class="data row12 col0" >орк</td>
#       <td id="T_b1c21_row12_col1" class="data row12 col1" >0.144</td>
#       <td id="T_b1c21_row12_col2" class="data row12 col2" >0.053</td>
#       <td id="T_b1c21_row12_col3" cl

# %% [markdown]
# Смотрим на важность героев по первой книге

# %%
# Разбиваем сегменты на три книги
segments_b1 = segments[:book1_end]
segments_b2 = segments[book1_end:book2_end]
segments_b3 = segments[book2_end:]

# Считаем метрики для каждой книги
df_1 = get_network_metrics(segments_b1, my_mapping)[0].set_index('Персонаж')
df_2 = get_network_metrics(segments_b2, my_mapping)[0].set_index('Персонаж')
df_3 = get_network_metrics(segments_b3, my_mapping)[0].set_index('Персонаж')

# Объединяем в одну таблицу, чтобы сравнить динамику "Связующей роли"
comparison_df = pd.DataFrame({
    'Хранители': df_1['Связующая роль'],
    'Две твердыни': df_2['Связующая роль'],
    'Возвращение государя': df_3['Связующая роль']
}).fillna(0) # Если героя нет в книге, ставим 0

# Фильтруем (убираем локации и оставляем только топ героев)
comparison_clean = comparison_df[~comparison_df.index.isin(blacklist)]
comparison_clean = comparison_clean.sort_values(by='Хранители', ascending=False).head(15)
comparison_clean.style.background_gradient(cmap='Oranges', axis=1).format("{:.3f}")
# Out:
# <style type="text/css">
# #T_a0fed_row0_col0, #T_a0fed_row1_col0, #T_a0fed_row2_col0, #T_a0fed_row3_col0, #T_a0fed_row4_col0, #T_a0fed_row5_col0, #T_a0fed_row6_col0, #T_a0fed_row7_col0, #T_a0fed_row8_col0, #T_a0fed_row9_col0, #T_a0fed_row10_col2, #T_a0fed_row11_col2, #T_a0fed_row12_col2, #T_a0fed_row13_col2, #T_a0fed_row14_col1 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_a0fed_row0_col1 {
#   background-color: #fdb678;
#   color: #000000;
# }
# #T_a0fed_row0_col2, #T_a0fed_row1_col1, #T_a0fed_row2_col1, #T_a0fed_row2_col2, #T_a0fed_row3_col1, #T_a0fed_row4_col1, #T_a0fed_row5_col1, #T_a0fed_row6_col1, #T_a0fed_row6_col2, #T_a0fed_row7_col1, #T_a0fed_row7_col2, #T_a0fed_row8_col1, #T_a0fed_row9_col1, #T_a0fed_row9_col2, #T_a0fed_row10_col1, #T_a0fed_row11_col0, #T_a0fed_row12_col1, #T_a0fed_row13_col1, #T_a0fed_row14_col2 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_a0fed_row1_col2 {
#   background-color: #ffefe0;
#   color: #000000;
# }
# #T_a0fed_row3_col2 {
#   background-color: #fff5ea;
#   color: #000000;
# }
# #T_a0fed_row4_col2 {
#   background-color: #f87d29;
#   color: #f1f1f1;
# }
# #T_a0fed_row5_col2 {
#   background-color: #fee2c7;
#   color: #000000;
# }
# #T_a0fed_row8_col2 {
#   background-color: #fff4e8;
#   color: #000000;
# }
# #T_a0fed_row10_col0 {
#   background-color: #f26d17;
#   color: #f1f1f1;
# }
# #T_a0fed_row11_col1 {
#   background-color: #fdd0a2;
#   color: #000000;
# }
# #T_a0fed_row12_col0 {
#   background-color: #fdc189;
#   color: #000000;
# }
# #T_a0fed_row13_col0 {
#   background-color: #fd9f56;
#   color: #000000;
# }
# #T_a0fed_row14_col0 {
#   background-color: #fdc48f;
#   color: #000000;
# }
# </style>
# <table id="T_a0fed">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0fed_level0_col0" class="col_heading level0 col0" >Хранители</th>
#       <th id="T_a0fed_level0_col1" class="col_heading level0 col1" >Две твердыни</th>
#       <th id="T_a0fed_level0_col2" class="col_heading level0 col2" >Возвращение государя</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Персонаж</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0fed_level0_row0" class="row_heading level0 row0" >сэм</th>
#       <td id="T_a0fed_row0_col0" class="data row0 col0" >0.278</td>
#       <td id="T_a0fed_row0_col1" class="data row0 col1" >0.108</td>
#       <td id="T_a0fed_row0_col2" class="data row0 col2" >0.019</td>
#     </tr>
#     <tr>
#       <th id="T_a0fed_level0_row1" class="row_heading level0 row1" >бильбо</th>
#       <td id="T_a0fed_row1_col0" class="data row1 col0" >0.244</td>
#       <td id="T_a0fed_row1_col1" class="data row1 col1" >0.000</td>
#       <td id="T_a0fed_row1_col2" class="data row1 col2" >0.012</td>
#     </tr>
#     <tr>
#       <th id="T_a0fed_level0_row2" class="row_heading level0 row2" >балин</th>
#       <td id="T_a0fed_row2_col0" class="data row2 col0" >0.220</td>
#       <td id="T_a0fed_row2_col1" class="data row2 col1" >0.000</td>
#       <td id="T_a0fed_row2_col2" class="data row2 col2" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_a0fed_level0_row3" class="row_heading level0 row3" >накручинс</th>
#       <td id="T_a0fed_row3_col0" class="data row3 col0" >0.111</td>
#       <td id="T_a0fed_row3_col1" class="data row3 col1" >0.000</td>
#       <td id="T_a0fed_row3_col2" class="data row3 col2" >0.001</td>
#     </tr>
#     <tr>
#       <th id="T_a0fed_level0_row4" class="row_heading level0 row4" >фродо</th>
#       <td id="T_a0fed_row4_col0" class="data row4 col0" >0.101</td>
#       <td id="T_a0fed_row4_col1" class="data row4 col1" >0.069</td>
#       <td id="T_a0fed_row4_col2" class="data row4 col2" >0.087</td>
#     </tr>
#     <tr>
#       <th id="T_a0fed_level0_row5" class="row_heading level0 row5" >андуин</th>
#       <td id="T_a0fed_row5_col0" class="data row5 col0" >0.099</td>
#       <td id="T_a0fed_row5_col1" class="data row5 col1" >0.000</td>
#       <td id="T_a0fed_row5_col2" class="data row5 col2" >0.015</td>
#     </tr>
#     <tr>
#       <th id="T_a0fed_level0_row6" class="row_heading level0 row6" >лучиэнь</th>
#       <td id="T_a0fed_row6_col0" class="data row6 col0" >0.098</td>
#       <td id="T_a0fed_row6_col1" class="data row6 col1" >0.000</td>
#       <td id="T_a0fed_row6_col2" class="data row6 col2" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_a0fed_level0_row7" class="row_heading level0 row7" >пескунс</th>
#       <td id="T_a0fed_row7_col0" class="data row7 col0" >0.088</td>
#       <td id="T_a0fed_row7_col1" class="data row7 col1" >0.000</td>
#       <td id="T_a0fed_row7_col2" class="data row7 col2" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_a0fed_level0_row8" class="row_heading level0 row8" >горислав</th>
#       <td id="T_a0fed_row8_col0" class="data row8 col0" >0.087</td>
#       <td id="T_a0fed_row8_col1" class="data row8 col1" >0.000</td>
#       <td id="T_a0fed_row8_col2" class="data row8 col2" >0.001</td>
#     </tr>
#     <tr>
#       <th id="T_a0fed_level0_row9" class="row_heading level0 row9" >исилдур</th>
#       <td id="T_a0fed_row9_col0" class="data row9 col0" >0.082</td>
#       <td id="T_a0fed_row9_col1" class="data row9 col1" >0.000</td>
#       <td id="T_a0fed_row9_col2" class="data row9 col2" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_a0fed_level0_row10" class="row_heading level0 row10" >гэндальф</th>
#       <td id="T_a0fed_row10_col0" class="data row10 col0" >0.076</td>
#       <td id="T_a0fed_row10_col1" class="data row10 col1" >0.051</td>
#       <td id="T_a0fed_row10_col2" class="data row10 col2" >0.092</td>
#     </tr>
#     <tr>
#       <th id="T_a0fed_level0_row11" class="row_heading level0 row11" >пин</th>
#       <td id="T_a0fed_row11_col0" class="data row11 col0" >0.076</td>
#       <td id="T_a0fed_row11_col1" class="data row11 col1" >0.129</td>
#       <td id="T_a0fed_row11_col2" class="data row11 col2" >0.287</td>
#     </tr>
#     <tr>
#       <th id="T_a0fed_level0_row12" class="row_heading level0 row12" >саурон</th>
#       <td id="T_a0fed_row12_col0" class="data row12 col0" >0.064</td>
#       <td id="T_a0fed_row12_col1" class="data row12 col1" >0.000</td>
#       <td id="T_a0fed_row12_col2" class="data row12 col2" >0.210</td>
#     </tr>
#     <tr>
#       <th id="T_a0fed_level0_row13" class="row_heading level0 row13" >арагорн</th>
#       <td id="T_a0fed_row13_col0" class="data row13 col0" >0.063</td>
#       <td id="T_a0fed_row13_col1" class="data row13 col1" >0.018</td>
#       <td id="T_a0fed_row13_col2" class="data row13 col2" >0.123</td>
#     </tr>
#     <tr>
#       <th id="T_a0fed_level0_row14" class="row_heading level0 row14" >леголас</th>
#       <td id="T_a0fed_row14_col0" class="data row14 col0" >0.055</td>
#       <td id="T_a0fed_row14_col1" class="data row14 col1" >0.150</td>
#       <td id="T_a0fed_row14_col2" class="data row14 col2" >0.015</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# Смотрим, как меняется роль ключевых героев в каждой книге

# %%
# Создаем временную колонку с суммой влияния во всех книгах
comparison_df['Total_Influence'] = comparison_df.sum(axis=1)

# Сортируем по этой сумме, чтобы в ТОП попали герои, важные хотя бы в одной из книг
comparison_clean = comparison_df[~comparison_df.index.isin(blacklist)]
comparison_clean = comparison_clean.sort_values(by='Total_Influence', ascending=False).head(15)

# Удаляем временную колонку перед отрисовкой, чтобы она не портила таблицу
comparison_clean = comparison_clean.drop(columns=['Total_Influence'])

# Выводим стиль
comparison_clean.style.background_gradient(cmap='Oranges', axis=1).format("{:.3f}")
# Out:
# <style type="text/css">
# #T_5af01_row0_col0, #T_5af01_row1_col2, #T_5af01_row2_col0, #T_5af01_row3_col1, #T_5af01_row4_col1, #T_5af01_row5_col1, #T_5af01_row6_col2, #T_5af01_row7_col1, #T_5af01_row7_col2, #T_5af01_row8_col2, #T_5af01_row9_col1, #T_5af01_row10_col1, #T_5af01_row11_col2, #T_5af01_row12_col2, #T_5af01_row13_col0, #T_5af01_row14_col1 {
#   background-color: #fff5eb;
#   color: #000000;
# }
# #T_5af01_row0_col1 {
#   background-color: #fdd0a2;
#   color: #000000;
# }
# #T_5af01_row0_col2, #T_5af01_row1_col0, #T_5af01_row2_col1, #T_5af01_row3_col2, #T_5af01_row4_col0, #T_5af01_row5_col0, #T_5af01_row6_col1, #T_5af01_row7_col0, #T_5af01_row8_col1, #T_5af01_row9_col2, #T_5af01_row10_col2, #T_5af01_row11_col1, #T_5af01_row12_col1, #T_5af01_row13_col1, #T_5af01_row14_col2 {
#   background-color: #7f2704;
#   color: #f1f1f1;
# }
# #T_5af01_row1_col1 {
#   background-color: #fdb678;
#   color: #000000;
# }
# #T_5af01_row2_col2 {
#   background-color: #ffeede;
#   color: #000000;
# }
# #T_5af01_row3_col0 {
#   background-color: #fdc189;
#   color: #000000;
# }
# #T_5af01_row4_col2 {
#   background-color: #f87d29;
#   color: #f1f1f1;
# }
# #T_5af01_row5_col2 {
#   background-color: #ffefe0;
#   color: #000000;
# }
# #T_5af01_row6_col0 {
#   background-color: #feead5;
#   color: #000000;
# }
# #T_5af01_row8_col0 {
#   background-color: #fdc48f;
#   color: #000000;
# }
# #T_5af01_row9_col0 {
#   background-color: #f26d17;
#   color: #f1f1f1;
# }
# #T_5af01_row10_col0 {
#   background-color: #fd9f56;
#   color: #000000;
# }
# #T_5af01_row11_col0 {
#   background-color: #feddbc;
#   color: #000000;
# }
# #T_5af01_row12_col0 {
#   background-color: #fdd1a4;
#   color: #000000;
# }
# #T_5af01_row13_col2 {
#   background-color: #fdd7af;
#   color: #000000;
# }
# #T_5af01_row14_col0 {
#   background-color: #fee6cf;
#   color: #000000;
# }
# </style>
# <table id="T_5af01">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5af01_level0_col0" class="col_heading level0 col0" >Хранители</th>
#       <th id="T_5af01_level0_col1" class="col_heading level0 col1" >Две твердыни</th>
#       <th id="T_5af01_level0_col2" class="col_heading level0 col2" >Возвращение государя</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Персонаж</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5af01_level0_row0" class="row_heading level0 row0" >пин</th>
#       <td id="T_5af01_row0_col0" class="data row0 col0" >0.076</td>
#       <td id="T_5af01_row0_col1" class="data row0 col1" >0.129</td>
#       <td id="T_5af01_row0_col2" class="data row0 col2" >0.287</td>
#     </tr>
#     <tr>
#       <th id="T_5af01_level0_row1" class="row_heading level0 row1" >сэм</th>
#       <td id="T_5af01_row1_col0" class="data row1 col0" >0.278</td>
#       <td id="T_5af01_row1_col1" class="data row1 col1" >0.108</td>
#       <td id="T_5af01_row1_col2" class="data row1 col2" >0.019</td>
#     </tr>
#     <tr>
#       <th id="T_5af01_level0_row2" class="row_heading level0 row2" >элронд</th>
#       <td id="T_5af01_row2_col0" class="data row2 col0" >0.026</td>
#       <td id="T_5af01_row2_col1" class="data row2 col1" >0.297</td>
#       <td id="T_5af01_row2_col2" class="data row2 col2" >0.041</td>
#     </tr>
#     <tr>
#       <th id="T_5af01_level0_row3" class="row_heading level0 row3" >саурон</th>
#       <td id="T_5af01_row3_col0" class="data row3 col0" >0.064</td>
#       <td id="T_5af01_row3_col1" class="data row3 col1" >0.000</td>
#       <td id="T_5af01_row3_col2" class="data row3 col2" >0.210</td>
#     </tr>
#     <tr>
#       <th id="T_5af01_level0_row4" class="row_heading level0 row4" >фродо</th>
#       <td id="T_5af01_row4_col0" class="data row4 col0" >0.101</td>
#       <td id="T_5af01_row4_col1" class="data row4 col1" >0.069</td>
#       <td id="T_5af01_row4_col2" class="data row4 col2" >0.087</td>
#     </tr>
#     <tr>
#       <th id="T_5af01_level0_row5" class="row_heading level0 row5" >бильбо</th>
#       <td id="T_5af01_row5_col0" class="data row5 col0" >0.244</td>
#       <td id="T_5af01_row5_col1" class="data row5 col1" >0.000</td>
#       <td id="T_5af01_row5_col2" class="data row5 col2" >0.012</td>
#     </tr>
#     <tr>
#       <th id="T_5af01_level0_row6" class="row_heading level0 row6" >горлум</th>
#       <td id="T_5af01_row6_col0" class="data row6 col0" >0.022</td>
#       <td id="T_5af01_row6_col1" class="data row6 col1" >0.233</td>
#       <td id="T_5af01_row6_col2" class="data row6 col2" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_5af01_level0_row7" class="row_heading level0 row7" >балин</th>
#       <td id="T_5af01_row7_col0" class="data row7 col0" >0.220</td>
#       <td id="T_5af01_row7_col1" class="data row7 col1" >0.000</td>
#       <td id="T_5af01_row7_col2" class="data row7 col2" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_5af01_level0_row8" class="row_heading level0 row8" >леголас</th>
#       <td id="T_5af01_row8_col0" class="data row8 col0" >0.055</td>
#       <td id="T_5af01_row8_col1" class="data row8 col1" >0.150</td>
#       <td id="T_5af01_row8_col2" class="data row8 col2" >0.015</td>
#     </tr>
#     <tr>
#       <th id="T_5af01_level0_row9" class="row_heading level0 row9" >гэндальф</th>
#       <td id="T_5af01_row9_col0" class="data row9 col0" >0.076</td>
#       <td id="T_5af01_row9_col1" class="data row9 col1" >0.051</td>
#       <td id="T_5af01_row9_col2" class="data row9 col2" >0.092</td>
#     </tr>
#     <tr>
#       <th id="T_5af01_level0_row10" class="row_heading level0 row10" >арагорн</th>
#       <td id="T_5af01_row10_col0" class="data row10 col0" >0.063</td>
#       <td id="T_5af01_row10_col1" class="data row10 col1" >0.018</td>
#       <td id="T_5af01_row10_col2" class="data row10 col2" >0.123</td>
#     </tr>
#     <tr>
#       <th id="T_5af01_level0_row11" class="row_heading level0 row11" >саруман</th>
#       <td id="T_5af01_row11_col0" class="data row11 col0" >0.029</td>
#       <td id="T_5af01_row11_col1" class="data row11 col1" >0.160</td>
#       <td id="T_5af01_row11_col2" class="data row11 col2" >0.000</td>
#     </tr>
#     <tr>
#       <th id="T_5af01_level0_row12" class="row_heading level0 row12" >мерри</th>
#       <td id="T_5af01_row12_col0" class="data row12 col0" >0.048</td>
#       <td id="T_5af01_row12_col1" class="data row12 col1" >0.106</td>
#       <td id="T_5af01_row12_col2" class="data row12 col2" >0.029</td>
#     </tr>
#     <tr>
#       <th id="T_5af01_level0_row13" class="row_heading level0 row13" >гимли</th>
#       <td id="T_5af01_row13_col0" class="data row13 col0" >0.002</td>
#       <td id="T_5af01_row13_col1" class="data row13 col1" >0.144</td>
#       <td id="T_5af01_row13_col2" class="data row13 col2" >0.032</td>
#     </tr>
#     <tr>
#       <th id="T_5af01_level0_row14" class="row_heading level0 row14" >элендил</th>
#       <td id="T_5af01_row14_col0" class="data row14 col0" >0.019</td>
#       <td id="T_5af01_row14_col1" class="data row14 col1" >0.000</td>
#       <td id="T_5af01_row14_col2" class="data row14 col2" >0.155</td>
#     </tr>
#   </tbody>
# </table>

# %%
final_results = {
    'global_metrics': df_final,
    'book_comparison': comparison_clean,
    'character_graph': G
}

with open('sna_final_results.pkl', 'wb') as f:
    pickle.dump(final_results, f)
